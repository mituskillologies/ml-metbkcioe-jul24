# %%
# data => wisc_bc_data.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('wisc_bc_data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
x = df.drop(['id', 'diagnosis'], axis = 1)
y = df['diagnosis']

# %%
# standard scaler
from sklearn.preprocessing import StandardScaler
sca = StandardScaler()
x_scaled = sca.fit_transform(x)

# %%
# cross validation
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y,
                                                   random_state=0,
                                                   stratify= y)

# %% [markdown]
# #### Build the neural network

# %%
from sklearn.neural_network import MLPClassifier

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
clf = MLPClassifier(hidden_layer_sizes=(64, 128, 128),
                   activation= 'relu',
                   max_iter= 50, verbose = True)

# %%
clf.fit(x_train, y_train)
# Out:
# Iteration 1, loss = 0.66377637
# Iteration 2, loss = 0.51441724
# Iteration 3, loss = 0.39848619
# Iteration 4, loss = 0.30710928
# Iteration 5, loss = 0.23572352
# Iteration 6, loss = 0.18410864
# Iteration 7, loss = 0.14857508
# Iteration 8, loss = 0.12275579
# Iteration 9, loss = 0.10625578
# Iteration 10, loss = 0.09515238
# Iteration 11, loss = 0.08556939
# Iteration 12, loss = 0.07837187
# Iteration 13, loss = 0.07235995
# Iteration 14, loss = 0.06700576
# Iteration 15, loss = 0.06258975
# Iteration 16, loss = 0.05892457
# Iteration 17, loss = 0.05562609
# Iteration 18, loss = 0.05266308
# Iteration 19, loss = 0.04977666
# Iteration 20, loss = 0.04689128
# Iteration 21, loss = 0.04463822
# Iteration 22, loss = 0.04085050
# Iteration 23, loss = 0.03964569
# Iteration 24, loss = 0.03750257
# Iteration 25, loss = 0.03604901
# Iteration 26, loss = 0.03363136
# Iteration 27, loss = 0.03273120
# Iteration 28, loss = 0.03112734
# Iteration 29, loss = 0.02868277
# Iteration 30, loss = 0.02641098
# Iteration 31, loss = 0.02447885
# Iteration 32, loss = 0.02364516
# Iteration 33, loss = 0.02303292
# Iteration 34, loss = 0.02153399
# Iteration 35, loss = 0.02010465
# Iteration 36, loss = 0.01891744
# Iteration 37, loss = 0.01775641
# Iteration 38, loss = 0.01727651
# Iteration 39, loss = 0.01673291
# Iteration 40, loss = 0.01580441
# Iteration 41, loss = 0.01458777
# Iteration 42, loss = 0.01336882
# Iteration 43, loss = 0.01251911
# Iteration 44, loss = 0.01198844
# Iteration 45, loss = 0.01092080
# Iteration 46, loss = 0.00988234
# Iteration 47, loss = 0.00899323
# Iteration 48, loss = 0.00846288
# Iteration 49, loss = 0.00779386
# Iteration 50, loss = 0.00732568
# MLPClassifier(hidden_layer_sizes=(64, 128, 128), max_iter=50, verbose=True)

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.972027972027972
