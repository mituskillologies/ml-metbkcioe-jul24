# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5, 5, 0.25)

# %%
x
# Out:
# array([-5.  , -4.75, -4.5 , -4.25, -4.  , -3.75, -3.5 , -3.25, -3.  ,
#        -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  , -0.75,
#        -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,
#         1.75,  2.  ,  2.25,  2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,
#         4.  ,  4.25,  4.5 ,  4.75])

# %%
y = 4.6 * x + 6.12

# %%
y
# Out:
# array([-16.88, -15.73, -14.58, -13.43, -12.28, -11.13,  -9.98,  -8.83,
#         -7.68,  -6.53,  -5.38,  -4.23,  -3.08,  -1.93,  -0.78,   0.37,
#          1.52,   2.67,   3.82,   4.97,   6.12,   7.27,   8.42,   9.57,
#         10.72,  11.87,  13.02,  14.17,  15.32,  16.47,  17.62,  18.77,
#         19.92,  21.07,  22.22,  23.37,  24.52,  25.67,  26.82,  27.97])

# %%
plt.plot(x, y);
